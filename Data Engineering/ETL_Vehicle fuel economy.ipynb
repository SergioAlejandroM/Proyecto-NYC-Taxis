# %%
import pandas as pd

# %%
data = pd.read_csv("../Data/Vehicle Fuel Economy Data.csv")
# Out:
# C:\Users\aje0v\AppData\Local\Temp\ipykernel_22656\1071883395.py:1: DtypeWarning: Columns (73,75) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("../Data/Vehicle Fuel Economy Data.csv")

# %%
display(data)
# Out:
#        Year Manufacturer                          Model  barrels08  \
# 0      2017          BMW                       M6 Coupe  17.500588
# 1      2017          BMW                   X3 sDrive28i  12.396250
# 2      2016     Infiniti                 Q50S Red Sport  13.523182
# 3      2017         MINI  John Cooper Works Convertible  11.018889
# 4      2017          Kia                      Sedona SX  14.167143
# ...     ...          ...                            ...        ...
# 46181  1993     Plymouth                Sundance/Duster  12.935217
# 46182  1993      Pontiac                       Grand Am  14.167143
# 46183  1993         Saab                            900  14.167143
# 46184  1993       Subaru                         Legacy  13.523182
# 46185  1993       Subaru                     Legacy AWD  14.167143
#
#        barrelsA08  charge240  city08  city08U  cityA08  cityA08U  ...  \
# 0             0.0        0.0    15.0     14.0      0.0       0.0  ...
# ...

# %%
columns_to_keep = ['Year','Manufacturer','Model', 'charge240','feScore', 'fuelCost08', 'fuelType1', 'VClass']

# %%
df_clean = data[columns_to_keep]

# %%
df_clean
# Out:
#        Year Manufacturer                          Model  charge240  feScore  \
# 0      2017          BMW                       M6 Coupe        0.0      3.0
# 1      2017          BMW                   X3 sDrive28i        0.0      5.0
# 2      2016     Infiniti                 Q50S Red Sport        0.0      5.0
# 3      2017         MINI  John Cooper Works Convertible        0.0      6.0
# 4      2017          Kia                      Sedona SX        0.0      4.0
# ...     ...          ...                            ...        ...      ...
# 46181  1993     Plymouth                Sundance/Duster        0.0     -1.0
# 46182  1993      Pontiac                       Grand Am        0.0     -1.0
# 46183  1993         Saab                            900        0.0      NaN
# 46184  1993       Subaru                         Legacy        0.0     -1.0
# 46185  1993       Subaru                     Legacy AWD        0.0     -1.0
#
# ...

# %%
Clases = ['Subcompact Cars','Compact Cars','Minicompact Cars']

# Filtrar el DataFrame por los modelos necesarios
filtered_df = df_clean[df_clean['VClass'].isin(Clases)]

# %%
filtered_df
# Out:
#        Year Manufacturer                          Model  charge240  feScore  \
# 0      2017          BMW                       M6 Coupe        0.0      3.0
# 3      2017         MINI  John Cooper Works Convertible        0.0      6.0
# 10     2017          BMW        650i xDrive Convertible        0.0      3.0
# 11     2017     Maserati                    GranTurismo        0.0      2.0
# 17     2017          Kia                            Rio        0.0      7.0
# ...     ...          ...                            ...        ...      ...
# 46179  1993   Oldsmobile                        Achieva        0.0     -1.0
# 46181  1993     Plymouth                Sundance/Duster        0.0     -1.0
# 46182  1993      Pontiac                       Grand Am        0.0     -1.0
# 46184  1993       Subaru                         Legacy        0.0     -1.0
# 46185  1993       Subaru                     Legacy AWD        0.0     -1.0
#
#        fuelCost08         fuelType1            VClass
# ...

# %%
filtered_df.to_csv("../Data/Data Procesada/Vehicle Fuel Economy clean.csv", index= False)
