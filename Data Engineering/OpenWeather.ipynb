# %%
import requests
import json

# %%
#  API Key
api_key = "d3640d848c6dfd03e4ff666d2788c9ec"

# Coordenadas
lat = "41.8781"
lon = "-87.6298"

# Construir la URL de la solicitud
url = f"https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={api_key}"

# Realizar la solicitud
response = requests.get(url)

# Procesar la respuesta
if response.status_code == 200:
    data = response.json()
    print(json.dumps(data, indent=4, ensure_ascii=False))
else:
    print(f"Error: {response.status_code}")
# Out:
# {
#     "coord": {
#         "lon": -87.6298,
#         "lat": 41.8781
#     },
#     "weather": [
#         {
#             "id": 803,
#             "main": "Clouds",
#             "description": "broken clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 302.69,
#         "feels_like": 305.31,
#         "temp_min": 300.36,
#         "temp_max": 304.34,
#         "pressure": 1010,
#         "humidity": 61,
#         "sea_level": 1010,
#         "grnd_level": 989
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 3.09,
#         "deg": 240
#     },
#     "clouds": {
#         "all": 75
#     },
#     "dt": 1722384368,
#     "sys": {
#         "type": 2,
#         "id": 2075214,
#         "country": "US",
#         "sunrise": 1722336163,
#         "sunset": 1722388257
#     },
#     "timezone": -18000,
#     "id": 4887398,
#     "name": "Chicago",
#     "cod": 200
# }
