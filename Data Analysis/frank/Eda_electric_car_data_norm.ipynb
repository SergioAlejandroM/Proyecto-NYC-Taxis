# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
Electric_car_data_norm = pd.read_csv(r'Data\ElectricCarData_Norm.csv')
Electric_car_data_norm.head(10)
# Out:
#          Brand                          Model     Accel  TopSpeed   Range  \
# 0       Tesla   Model 3 Long Range Dual Motor   4.6 sec  233 km/h  450 km
# 1  Volkswagen                       ID.3 Pure  10.0 sec  160 km/h  270 km
# 2    Polestar                               2   4.7 sec  210 km/h  400 km
# 3         BMW                            iX3    6.8 sec  180 km/h  360 km
# 4       Honda                              e    9.5 sec  145 km/h  170 km
# 5       Lucid                            Air    2.8 sec  250 km/h  610 km
# 6  Volkswagen                         e-Golf    9.6 sec  150 km/h  190 km
# 7     Peugeot                          e-208    8.1 sec  150 km/h  275 km
# 8       Tesla     Model 3 Standard Range Plus   5.6 sec  225 km/h  310 km
# 9        Audi                      Q4 e-tron    6.3 sec  180 km/h  400 km
#
#   Efficiency FastCharge              RapidCharge         PowerTrain  \
# 0  161 Wh/km   940 km/h  Rapid charging possible    All Wheel Drive
# ...

# %%
Electric_car_data_norm.tail(5)
# Out:
#        Brand                            Model    Accel  TopSpeed   Range  \
# 98   Nissan                       Ariya 63kWh  7.5 sec  160 km/h  330 km
# 99     Audi     e-tron S Sportback 55 quattro  4.5 sec  210 km/h  335 km
# 100  Nissan               Ariya e-4ORCE 63kWh  5.9 sec  200 km/h  325 km
# 101  Nissan   Ariya e-4ORCE 87kWh Performance  5.1 sec  200 km/h  375 km
# 102   Byton                 M-Byte 95 kWh 2WD  7.5 sec  190 km/h  400 km
#
#     Efficiency FastCharge              RapidCharge         PowerTrain  \
# 98   191 Wh/km   440 km/h  Rapid charging possible  Front Wheel Drive
# 99   258 Wh/km   540 km/h  Rapid charging possible    All Wheel Drive
# 100  194 Wh/km   440 km/h  Rapid charging possible    All Wheel Drive
# 101  232 Wh/km   450 km/h  Rapid charging possible    All Wheel Drive
# 102  238 Wh/km   480 km/h  Rapid charging possible    All Wheel Drive
#
#        PlugType  BodyStyle Segment  Seats  PriceEuro
# ...

# %%
# Información de las columnas
print(Electric_car_data_norm.columns)
# Out:
# Index(['Brand', 'Model', 'Accel', 'TopSpeed', 'Range', 'Efficiency',
#        'FastCharge', 'RapidCharge', 'PowerTrain', 'PlugType', 'BodyStyle',
#        'Segment', 'Seats', 'PriceEuro'],
#       dtype='object')

# %%
# Información general del dataset
print(Electric_car_data_norm.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Brand        103 non-null    object
#  1   Model        103 non-null    object
#  2   Accel        103 non-null    object
#  3   TopSpeed     103 non-null    object
#  4   Range        103 non-null    object
#  5   Efficiency   103 non-null    object
#  6   FastCharge   103 non-null    object
#  7   RapidCharge  103 non-null    object
#  8   PowerTrain   103 non-null    object
#  9   PlugType     103 non-null    object
#  10  BodyStyle    103 non-null    object
#  11  Segment      103 non-null    object
#  12  Seats        103 non-null    int64
#  13  PriceEuro    103 non-null    int64
# dtypes: int64(2), object(12)
# memory usage: 11.4+ KB
# None

# %%
# Describir las estadísticas básicas del dataset
print(Electric_car_data_norm.describe())
# Out:
#             Seats      PriceEuro
# count  103.000000     103.000000
# mean     4.883495   55811.563107
# std      0.795834   34134.665280
# min      2.000000   20129.000000
# 25%      5.000000   34429.500000
# 50%      5.000000   45000.000000
# 75%      5.000000   65000.000000
# max      7.000000  215000.000000

# %%
# Descripción estadística de las columnas numéricas
print(Electric_car_data_norm.describe())
# Out:
#             Seats      PriceEuro
# count  103.000000     103.000000
# mean     4.883495   55811.563107
# std      0.795834   34134.665280
# min      2.000000   20129.000000
# 25%      5.000000   34429.500000
# 50%      5.000000   45000.000000
# 75%      5.000000   65000.000000
# max      7.000000  215000.000000

# %%
# Descripción estadística de las columnas categóricas

print(Electric_car_data_norm.describe(include=['object']))
# Out:
#          Brand          Model    Accel  TopSpeed   Range Efficiency  \
# count      103            103      103       103     103        103
# unique      33            102       55        25      50         54
# top     Tesla   e-Soul 64 kWh  9.0 sec  160 km/h  250 km  168 Wh/km
# freq        13              2        7        15       6          6
#
#        FastCharge              RapidCharge       PowerTrain    PlugType  \
# count         103                      103              103         103
# unique         51                        2                3           4
# top      230 km/h  Rapid charging possible  All Wheel Drive  Type 2 CCS
# freq            6                       98               41          90
#
#        BodyStyle Segment
# count        103     103
# unique         9       8
# top          SUV       C
# freq          45      30

# %%
# Verificar el total de valores nulos por columna
print(Electric_car_data_norm.isnull().sum())
# Out:
# Brand          0
# Model          0
# Accel          0
# TopSpeed       0
# Range          0
# Efficiency     0
# FastCharge     0
# RapidCharge    0
# PowerTrain     0
# PlugType       0
# BodyStyle      0
# Segment        0
# Seats          0
# PriceEuro      0
# dtype: int64

# %%
# Verificar el porcentaje de valores nulos por columna
print((Electric_car_data_norm.isnull().sum() / len(Electric_car_data_norm)) * 100)
# Out:
# Brand          0.0
# Model          0.0
# Accel          0.0
# TopSpeed       0.0
# Range          0.0
# Efficiency     0.0
# FastCharge     0.0
# RapidCharge    0.0
# PowerTrain     0.0
# PlugType       0.0
# BodyStyle      0.0
# Segment        0.0
# Seats          0.0
# PriceEuro      0.0
# dtype: float64

# %%
# Verificar si hay duplicados
print(Electric_car_data_norm.duplicated().sum())
# Out:
# 0

# %%
# Histogramas para ver la distribución de las variables numéricas
Electric_car_data_norm.hist(bins=30, figsize=(20, 15))
plt.show()
