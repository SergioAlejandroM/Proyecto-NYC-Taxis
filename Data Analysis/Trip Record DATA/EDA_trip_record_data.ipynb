# %%
#Importación de librerías y extracción de data

import requests
from bs4 import BeautifulSoup
import os
import re

# URL de la página
url = "https://www.nyc.gov/site/tlc/about/tlc-trip-record-data.page"

# Realizar la solicitud GET a la página
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

# Crear una carpeta para almacenar los archivos descargados
os.makedirs('parquet_files', exist_ok=True)

# Función para verificar si el archivo está dentro del rango de años
def is_within_year_range(file_name, start_year, end_year):
    match = re.search(r'(\d{4})', file_name)
    if match:
        year = int(match.group(1))
        return start_year >= year >= end_year
    return False

# Rango de años
start_year = 2023
end_year = 2017

# Buscar todos los enlaces de archivos Parquet
for link in soup.find_all('a', href=True):
    href = link['href']
    if href.endswith('.parquet'):
        file_name = href.split('/')[-1]
        # Filtrar solo archivos que contengan 'green_tripdata' o 'yellow_tripdata' y estén en el rango de años
        if ('green_tripdata' in file_name or 'yellow_tripdata' in file_name) and is_within_year_range(file_name, start_year, end_year):
            # Descargar el archivo
            file_url = href
            file_response = requests.get(file_url)
            with open(os.path.join('parquet_files', file_name), 'wb') as file:
                file.write(file_response.content)
            
            print(f"Descargado: {file_name}")

print("Descarga completada.")
# Out:
# Descargado: yellow_tripdata_2023-01.parquet
# Descargado: green_tripdata_2023-01.parquet
# Descargado: yellow_tripdata_2023-02.parquet
# Descargado: green_tripdata_2023-02.parquet
# Descargado: yellow_tripdata_2023-03.parquet
# Descargado: yellow_tripdata_2023-04.parquet
# Descargado: green_tripdata_2023-04.parquet
# Descargado: yellow_tripdata_2023-06.parquet
# Descargado: green_tripdata_2023-06.parquet
# Descargado: yellow_tripdata_2023-12.parquet
# Descargado: green_tripdata_2023-12.parquet
# Descargado: yellow_tripdata_2022-01.parquet
# Descargado: green_tripdata_2022-01.parquet
# Descargado: yellow_tripdata_2022-02.parquet
# Descargado: green_tripdata_2022-02.parquet
# Descargado: yellow_tripdata_2022-03.parquet
# Descargado: green_tripdata_2022-03.parquet
# Descargado: yellow_tripdata_2022-04.parquet
# Descargado: green_tripdata_2022-04.parquet
# Descargado: yellow_tripdata_2022-05.parquet
# Descargado: green_tripdata_2022-05.parquet
# Descargado: yellow_tripdata_2022-06.parquet
# Descargado: green_tripdata_2022-06.parquet
# Descargado: yellow_tripdata_2022-07.parquet
# Descargado: green_tripdata_2022-07.parquet
# Descargado: yellow_tripdata_2022-08.parquet
# Descargado: green_tripdata_2022-08.parquet
# Descargado: yellow_tripdata_2022-09.parquet
# Descargado: green_tripdata_2022-09.parquet
# Descargado: yellow_tripdata_2022-10.parquet
# Descargado: green_tripdata_2022-10.parquet
# Descargado: yellow_tripdata_2022-11.parquet
# Descargado: green_tripdata_2022-11.parquet
# Descargado: yellow_tripdata_2022-12.parquet
# Descargado: green_tripdata_2022-12.parquet
# Descargado: yellow_tripdata_2021-01.parquet
# Descargado: green_tripdata_2021-01.parquet
# Descargado: yellow_tripdata_2021-02.parquet
# Descargado: green_tripdata_2021-02.parquet
# Descargado: yellow_tripdata_2021-03.parquet
# Descargado: green_tripdata_2021-03.parquet
# Descargado: yellow_tripdata_2021-04.parquet
# Descargado: green_tripdata_2021-04.parquet
# Descargado: yellow_tripdata_2021-05.parquet
# Descargado: green_tripdata_2021-05.parquet
# Descargado: yellow_tripdata_2021-06.parquet
# Descargado: green_tripdata_2021-06.parquet
# Descargado: yellow_tripdata_2021-07.parquet
# Descargado: green_tripdata_2021-07.parquet
# Descargado: yellow_tripdata_2021-08.parquet
# Descargado: green_tripdata_2021-08.parquet
# Descargado: yellow_tripdata_2021-09.parquet
# Descargado: green_tripdata_2021-09.parquet
# Descargado: yellow_tripdata_2021-10.parquet
# Descargado: green_tripdata_2021-10.parquet
# Descargado: yellow_tripdata_2021-11.parquet
# Descargado: green_tripdata_2021-11.parquet
# Descargado: yellow_tripdata_2021-12.parquet
# Descargado: green_tripdata_2021-12.parquet
# Descargado: yellow_tripdata_2020-01.parquet
# Descargado: green_tripdata_2020-01.parquet
# Descargado: yellow_tripdata_2020-02.parquet
# Descargado: green_tripdata_2020-02.parquet
# Descargado: yellow_tripdata_2020-03.parquet
# Descargado: green_tripdata_2020-03.parquet
# Descargado: yellow_tripdata_2020-04.parquet
# Descargado: green_tripdata_2020-04.parquet
# Descargado: yellow_tripdata_2020-05.parquet
# Descargado: green_tripdata_2020-05.parquet
# Descargado: yellow_tripdata_2020-06.parquet
# Descargado: green_tripdata_2020-06.parquet
# Descargado: yellow_tripdata_2020-07.parquet
# Descargado: green_tripdata_2020-07.parquet
# Descargado: yellow_tripdata_2020-08.parquet
# Descargado: green_tripdata_2020-08.parquet
# Descargado: yellow_tripdata_2020-09.parquet
# Descargado: green_tripdata_2020-09.parquet
# Descargado: yellow_tripdata_2020-10.parquet
# Descargado: green_tripdata_2020-10.parquet
# Descargado: yellow_tripdata_2020-11.parquet
# Descargado: green_tripdata_2020-11.parquet
# Descargado: yellow_tripdata_2020-12.parquet
# Descargado: green_tripdata_2020-12.parquet
# Descargado: yellow_tripdata_2019-01.parquet
# Descargado: green_tripdata_2019-01.parquet
# Descargado: yellow_tripdata_2019-02.parquet
# Descargado: green_tripdata_2019-02.parquet
# Descargado: yellow_tripdata_2019-03.parquet
# Descargado: green_tripdata_2019-03.parquet
# Descargado: yellow_tripdata_2019-04.parquet
# Descargado: green_tripdata_2019-04.parquet
# Descargado: yellow_tripdata_2019-05.parquet
# Descargado: green_tripdata_2019-05.parquet
# Descargado: yellow_tripdata_2019-06.parquet
# Descargado: green_tripdata_2019-06.parquet
# Descargado: yellow_tripdata_2019-07.parquet
# Descargado: green_tripdata_2019-07.parquet
# Descargado: yellow_tripdata_2019-08.parquet
# Descargado: green_tripdata_2019-08.parquet
# Descargado: yellow_tripdata_2019-09.parquet
# Descargado: green_tripdata_2019-09.parquet
# Descargado: yellow_tripdata_2019-10.parquet
# Descargado: green_tripdata_2019-10.parquet
# Descargado: yellow_tripdata_2019-11.parquet
# Descargado: green_tripdata_2019-11.parquet
# Descargado: yellow_tripdata_2019-12.parquet
# Descargado: green_tripdata_2019-12.parquet
# Descargado: yellow_tripdata_2018-01.parquet
# Descargado: green_tripdata_2018-01.parquet
# Descargado: yellow_tripdata_2018-02.parquet
# Descargado: green_tripdata_2018-02.parquet
# Descargado: yellow_tripdata_2018-03.parquet
# Descargado: green_tripdata_2018-03.parquet
# Descargado: yellow_tripdata_2018-04.parquet
# Descargado: green_tripdata_2018-04.parquet
# Descargado: yellow_tripdata_2018-05.parquet
# Descargado: green_tripdata_2018-05.parquet
# Descargado: yellow_tripdata_2018-06.parquet
# Descargado: green_tripdata_2018-06.parquet
# Descargado: yellow_tripdata_2018-07.parquet
# Descargado: green_tripdata_2018-07.parquet
# Descargado: yellow_tripdata_2018-08.parquet
# Descargado: green_tripdata_2018-08.parquet
# Descargado: yellow_tripdata_2018-09.parquet
# Descargado: green_tripdata_2018-09.parquet
# Descargado: yellow_tripdata_2018-10.parquet
# Descargado: green_tripdata_2018-10.parquet
# Descargado: yellow_tripdata_2018-11.parquet
# Descargado: green_tripdata_2018-11.parquet
# Descargado: yellow_tripdata_2018-12.parquet
# Descargado: green_tripdata_2018-12.parquet
# Descargado: yellow_tripdata_2017-01.parquet
# Descargado: green_tripdata_2017-01.parquet
# Descargado: yellow_tripdata_2017-02.parquet
# Descargado: green_tripdata_2017-02.parquet
# Descargado: yellow_tripdata_2017-03.parquet
# Descargado: green_tripdata_2017-03.parquet
# Descargado: yellow_tripdata_2017-04.parquet
# Descargado: green_tripdata_2017-04.parquet
# Descargado: yellow_tripdata_2017-05.parquet
# Descargado: green_tripdata_2017-05.parquet
# Descargado: yellow_tripdata_2017-06.parquet
# Descargado: green_tripdata_2017-06.parquet
# Descargado: yellow_tripdata_2017-07.parquet
# Descargado: green_tripdata_2017-07.parquet
# Descargado: yellow_tripdata_2017-08.parquet
# Descargado: green_tripdata_2017-08.parquet
# Descargado: yellow_tripdata_2017-09.parquet
# Descargado: green_tripdata_2017-09.parquet
# Descargado: yellow_tripdata_2017-10.parquet
# Descargado: green_tripdata_2017-10.parquet
# Descargado: yellow_tripdata_2017-11.parquet
# Descargado: green_tripdata_2017-11.parquet
# Descargado: yellow_tripdata_2017-12.parquet
# Descargado: green_tripdata_2017-12.parquet
# Descarga completada.

# %%
#Leer archivo parquet

#importacion de librerias
import pandas as pd

#rutas a los archivos
file_path_greentaxis = './parquet_files/green_tripdata_2023-06.parquet'
file_path_yellowtaxis = './parquet_files/yellow_tripdata_2023-06.parquet'

#dataframe
df_green_taxis = pd.read_parquet(file_path_greentaxis)
df_yellow_taxis = pd.read_parquet(file_path_yellowtaxis)

# %%
df_green_taxis
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0             2  2023-06-01 00:32:25   2023-06-01 00:39:06                  N
# 1             2  2023-06-01 00:39:07   2023-06-01 00:51:59                  N
# 2             2  2023-06-01 00:35:59   2023-06-01 00:57:06                  N
# 3             2  2023-06-01 00:50:29   2023-06-01 01:00:32                  N
# 4             2  2023-06-01 00:15:15   2023-06-01 00:52:40                  N
# ...         ...                  ...                   ...                ...
# 65545         2  2023-06-30 23:09:00   2023-06-30 23:16:00               None
# 65546         2  2023-06-30 23:31:00   2023-06-30 23:41:00               None
# 65547         2  2023-06-30 23:03:00   2023-06-30 23:22:00               None
# 65548         2  2023-06-30 23:12:00   2023-06-30 23:32:00               None
# 65549         2  2023-06-30 23:36:00   2023-06-30 23:48:00               None
#
#        RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0             1.0            74            42              1.0           0.84
# 1             1.0            41           229              1.0           4.05
# 2             1.0            97            89              1.0           4.26
# 3             1.0            75           263              1.0           1.79
# 4             1.0            33            48              1.0           6.40
# ...           ...           ...           ...              ...            ...
# 65545         NaN            75           263              NaN           1.49
# 65546         NaN           223           260              NaN           3.05
# 65547         NaN           134           180              NaN           3.75
# 65548         NaN            33           157              NaN           5.29
# 65549         NaN           152            41              NaN           1.82
#
#        fare_amount  extra  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# 0             7.90    1.0      0.5        2.08           0.0        NaN
# 1            19.10    1.0      0.5        3.65           0.0        NaN
# 2            23.30    1.0      0.5        5.16           0.0        NaN
# 3            12.10    1.0      0.5        3.47           0.0        NaN
# 4            37.30    1.0      0.5        0.00           0.0        NaN
# ...            ...    ...      ...         ...           ...        ...
# 65545        13.24    0.0      0.0        3.40           0.0        NaN
# 65546        13.76    0.0      0.0        2.95           0.0        NaN
# 65547        19.93    0.0      0.0        1.05           0.0        NaN
# 65548        27.20    0.0      0.0        5.64           0.0        NaN
# 65549        13.24    0.0      0.0        2.85           0.0        NaN
#
#        improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                        1.0         12.48           1.0        1.0
# 1                        1.0         28.00           1.0        1.0
# 2                        1.0         30.96           1.0        1.0
# 3                        1.0         20.82           1.0        1.0
# 4                        1.0         42.55           1.0        1.0
# ...                      ...           ...           ...        ...
# 65545                    1.0         20.39           NaN        NaN
# 65546                    1.0         17.71           NaN        NaN
# 65547                    1.0         21.98           NaN        NaN
# 65548                    1.0         33.84           NaN        NaN
# 65549                    1.0         17.09           NaN        NaN
#
#        congestion_surcharge
# 0                      0.00
# 1                      2.75
# 2                      0.00
# 3                      2.75
# 4                      2.75
# ...                     ...
# 65545                   NaN
# 65546                   NaN
# 65547                   NaN
# 65548                   NaN
# 65549                   NaN
#
# [65550 rows x 20 columns]

# %%
df_green_taxis.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2023-06-01 00:32:25   2023-06-01 00:39:06                  N
# 1         2  2023-06-01 00:39:07   2023-06-01 00:51:59                  N
# 2         2  2023-06-01 00:35:59   2023-06-01 00:57:06                  N
# 3         2  2023-06-01 00:50:29   2023-06-01 01:00:32                  N
# 4         2  2023-06-01 00:15:15   2023-06-01 00:52:40                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0            74            42              1.0           0.84
# 1         1.0            41           229              1.0           4.05
# 2         1.0            97            89              1.0           4.26
# 3         1.0            75           263              1.0           1.79
# 4         1.0            33            48              1.0           6.40
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# 0          7.9    1.0      0.5        2.08           0.0        NaN
# 1         19.1    1.0      0.5        3.65           0.0        NaN
# 2         23.3    1.0      0.5        5.16           0.0        NaN
# 3         12.1    1.0      0.5        3.47           0.0        NaN
# 4         37.3    1.0      0.5        0.00           0.0        NaN
#
#    improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                    1.0         12.48           1.0        1.0
# 1                    1.0         28.00           1.0        1.0
# 2                    1.0         30.96           1.0        1.0
# 3                    1.0         20.82           1.0        1.0
# 4                    1.0         42.55           1.0        1.0
#
#    congestion_surcharge
# 0                  0.00
# 1                  2.75
# 2                  0.00
# 3                  2.75
# 4                  2.75

# %%
df_green_taxis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65550 entries, 0 to 65549
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorID               65550 non-null  int32
#  1   lpep_pickup_datetime   65550 non-null  datetime64[us]
#  2   lpep_dropoff_datetime  65550 non-null  datetime64[us]
#  3   store_and_fwd_flag     60359 non-null  object
#  4   RatecodeID             60359 non-null  float64
#  5   PULocationID           65550 non-null  int32
#  6   DOLocationID           65550 non-null  int32
#  7   passenger_count        60359 non-null  float64
#  8   trip_distance          65550 non-null  float64
#  9   fare_amount            65550 non-null  float64
#  10  extra                  65550 non-null  float64
#  11  mta_tax                65550 non-null  float64
#  12  tip_amount             65550 non-null  float64
#  13  tolls_amount           65550 non-null  float64
#  14  ehail_fee              0 non-null      float64
#  15  improvement_surcharge  65550 non-null  float64
#  16  total_amount           65550 non-null  float64
#  17  payment_type           60359 non-null  float64
#  18  trip_type              60359 non-null  float64
#  19  congestion_surcharge   60359 non-null  float64
# dtypes: datetime64[us](2), float64(14), int32(3), object(1)
# memory usage: 9.3+ MB

# %%
print(df_green_taxis.describe())
# Out:
#            VendorID        lpep_pickup_datetime       lpep_dropoff_datetime  \
# count  65550.000000                       65550                       65550
# mean       1.875057  2023-06-15 18:02:19.476171  2023-06-15 18:22:14.300656
# min        1.000000         2023-05-26 01:58:10         2023-05-26 01:58:13
# 25%        2.000000  2023-06-08 09:16:17.750000  2023-06-08 09:32:55.750000
# 50%        2.000000         2023-06-15 12:55:04         2023-06-15 13:14:31
# 75%        2.000000  2023-06-23 00:11:16.500000  2023-06-23 00:29:22.250000
# max        2.000000         2023-07-01 23:59:30         2023-07-02 00:32:47
# std        0.330657                         NaN                         NaN
#
#          RatecodeID  PULocationID  DOLocationID  passenger_count  \
# count  60359.000000  65550.000000  65550.000000     60359.000000
# mean       1.160076     98.453059    139.621876         1.283007
# min        1.000000      1.000000      1.000000         0.000000
# 25%        1.000000     74.000000     74.000000         1.000000
# 50%        1.000000     75.000000    138.000000         1.000000
# 75%        1.000000    127.000000    223.000000         1.000000
# max        6.000000    265.000000    265.000000         9.000000
# std        0.772654     60.833665     76.726747         0.904936
#
#        trip_distance   fare_amount         extra       mta_tax    tip_amount  \
# count   65550.000000  65550.000000  65550.000000  65550.000000  65550.000000
# mean       22.430450     18.892448      0.882613      0.561037      2.415067
# min         0.000000   -240.000000     -2.500000     -0.500000     -0.900000
# 25%         1.180000     10.000000      0.000000      0.500000      0.000000
# 50%         1.980000     14.200000      0.000000      0.500000      1.940000
# 75%         3.600000     21.980000      1.000000      0.500000      3.690000
# max    179375.160000   4003.000000     10.000000      1.500000     96.300000
# std      1114.401748     22.605564      1.327904      0.381443      3.308543
#
#        tolls_amount  ehail_fee  improvement_surcharge  total_amount  \
# count  65550.000000        0.0           65550.000000  65550.000000
# mean       0.253476        NaN               0.985623     24.530728
# min        0.000000        NaN              -1.000000   -241.000000
# 25%        0.000000        NaN               1.000000     13.640000
# 50%        0.000000        NaN               1.000000     19.500000
# 75%        0.000000        NaN               1.000000     29.000000
# max       29.500000        NaN               1.000000   4004.500000
# std        1.355565        NaN               0.132579     24.247960
#
#        payment_type     trip_type  congestion_surcharge
# count  60359.000000  60359.000000          60359.000000
# mean       1.346079      1.035537              0.746947
# min        1.000000      1.000000             -2.750000
# 25%        1.000000      1.000000              0.000000
# 50%        1.000000      1.000000              0.000000
# 75%        2.000000      1.000000              2.750000
# max        5.000000      2.000000              2.750000
# std        0.501658      0.185135              1.223115

# %%
df_green_taxis.columns
# Out:
# Index(['VendorID', 'lpep_pickup_datetime', 'lpep_dropoff_datetime',
#        'store_and_fwd_flag', 'RatecodeID', 'PULocationID', 'DOLocationID',
#        'passenger_count', 'trip_distance', 'fare_amount', 'extra', 'mta_tax',
#        'tip_amount', 'tolls_amount', 'ehail_fee', 'improvement_surcharge',
#        'total_amount', 'payment_type', 'trip_type', 'congestion_surcharge'],
#       dtype='object')

# %%
df_green_taxis.shape
# Out:
# (65550, 20)

# %%
df_yellow_taxis
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2023-06-01 00:08:48   2023-06-01 00:29:41              1.0
# 1               1  2023-06-01 00:15:04   2023-06-01 00:25:18              0.0
# 2               1  2023-06-01 00:48:24   2023-06-01 01:07:07              1.0
# 3               2  2023-06-01 00:54:03   2023-06-01 01:17:29              3.0
# 4               2  2023-06-01 00:18:44   2023-06-01 00:27:18              1.0
# ...           ...                  ...                   ...              ...
# 3307229         2  2023-06-30 23:30:21   2023-07-01 00:00:46              NaN
# 3307230         1  2023-06-30 23:34:22   2023-07-01 00:32:59              NaN
# 3307231         2  2023-06-30 23:45:00   2023-07-01 00:10:00              NaN
# 3307232         2  2023-06-30 23:13:38   2023-06-30 23:51:19              NaN
# 3307233         2  2023-06-30 23:18:00   2023-06-30 23:31:00              NaN
#
#          trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 0                 3.40         1.0                  N           140
# 1                 3.40         1.0                  N            50
# 2                10.20         1.0                  N           138
# 3                 9.83         1.0                  N           100
# 4                 1.17         1.0                  N           137
# ...                ...         ...                ...           ...
# 3307229           9.20         NaN               None            42
# 3307230          20.20         NaN               None           132
# 3307231           6.16         NaN               None           256
# 3307232          11.65         NaN               None            91
# 3307233           1.40         NaN               None           164
#
#          DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 0                 238             1        21.90   3.50      0.5        6.70
# 1                 151             1        15.60   3.50      0.5        3.00
# 2                  97             1        40.80   7.75      0.5       10.00
# 3                 244             1        39.40   1.00      0.5        8.88
# 4                 234             1         9.30   1.00      0.5        0.72
# ...               ...           ...          ...    ...      ...         ...
# 3307229           148             0        38.53   0.00      0.5        8.51
# 3307230            74             0        70.00   1.75      0.5       11.97
# 3307231           140             0        28.03   0.00      0.5        6.41
# 3307232           246             0        45.74   0.00      0.5        0.00
# 3307233           230             0        14.35   0.00      0.5        0.00
#
#          tolls_amount  improvement_surcharge  total_amount  \
# 0                0.00                    1.0         33.60
# 1                0.00                    1.0         23.60
# 2                0.00                    1.0         60.05
# 3                0.00                    1.0         53.28
# 4                0.00                    1.0         15.02
# ...               ...                    ...           ...
# 3307229          0.00                    1.0         51.04
# 3307230          6.55                    1.0         91.77
# 3307231          0.00                    1.0         38.44
# 3307232          6.55                    1.0         56.29
# 3307233          0.00                    1.0         18.35
#
#          congestion_surcharge  Airport_fee
# 0                         2.5         0.00
# 1                         2.5         0.00
# 2                         0.0         1.75
# 3                         2.5         0.00
# 4                         2.5         0.00
# ...                       ...          ...
# 3307229                   NaN          NaN
# 3307230                   NaN          NaN
# 3307231                   NaN          NaN
# 3307232                   NaN          NaN
# 3307233                   NaN          NaN
#
# [3307234 rows x 19 columns]

# %%
df_yellow_taxis.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2023-06-01 00:08:48   2023-06-01 00:29:41              1.0
# 1         1  2023-06-01 00:15:04   2023-06-01 00:25:18              0.0
# 2         1  2023-06-01 00:48:24   2023-06-01 01:07:07              1.0
# 3         2  2023-06-01 00:54:03   2023-06-01 01:17:29              3.0
# 4         2  2023-06-01 00:18:44   2023-06-01 00:27:18              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           3.40         1.0                  N           140           238
# 1           3.40         1.0                  N            50           151
# 2          10.20         1.0                  N           138            97
# 3           9.83         1.0                  N           100           244
# 4           1.17         1.0                  N           137           234
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             1         21.9   3.50      0.5        6.70           0.0
# 1             1         15.6   3.50      0.5        3.00           0.0
# 2             1         40.8   7.75      0.5       10.00           0.0
# 3             1         39.4   1.00      0.5        8.88           0.0
# 4             1          9.3   1.00      0.5        0.72           0.0
#
#    improvement_surcharge  total_amount  congestion_surcharge  Airport_fee
# 0                    1.0         33.60                   2.5         0.00
# 1                    1.0         23.60                   2.5         0.00
# 2                    1.0         60.05                   0.0         1.75
# 3                    1.0         53.28                   2.5         0.00
# 4                    1.0         15.02                   2.5         0.00

# %%
df_yellow_taxis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3307234 entries, 0 to 3307233
# Data columns (total 19 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               int32
#  1   tpep_pickup_datetime   datetime64[us]
#  2   tpep_dropoff_datetime  datetime64[us]
#  3   passenger_count        float64
#  4   trip_distance          float64
#  5   RatecodeID             float64
#  6   store_and_fwd_flag     object
#  7   PULocationID           int32
#  8   DOLocationID           int32
#  9   payment_type           int64
#  10  fare_amount            float64
#  11  extra                  float64
#  12  mta_tax                float64
#  13  tip_amount             float64
#  14  tolls_amount           float64
#  15  improvement_surcharge  float64
#  16  total_amount           float64
#  17  congestion_surcharge   float64
#  18  Airport_fee            float64
# dtypes: datetime64[us](2), float64(12), int32(3), int64(1), object(1)
# memory usage: 441.6+ MB

# %%
print(df_yellow_taxis.describe())
# Out:
#            VendorID        tpep_pickup_datetime       tpep_dropoff_datetime  \
# count  3.307234e+06                     3307234                     3307234
# mean   1.737262e+00  2023-06-15 18:09:27.394469  2023-06-15 18:27:09.958314
# min    1.000000e+00         2002-12-31 23:03:19         2002-12-31 23:06:17
# 25%    1.000000e+00  2023-06-08 09:12:42.250000  2023-06-08 09:30:06.250000
# 50%    2.000000e+00  2023-06-15 14:15:24.500000         2023-06-15 14:36:09
# 75%    2.000000e+00         2023-06-23 02:25:20  2023-06-23 02:40:05.750000
# max    6.000000e+00         2023-07-01 00:42:13         2023-07-03 16:31:24
# std    4.477026e-01                         NaN                         NaN
#
#        passenger_count  trip_distance    RatecodeID  PULocationID  \
# count     3.207347e+06   3.307234e+06  3.207347e+06  3.307234e+06
# mean      1.369012e+00   4.368790e+00  1.547159e+00  1.649028e+02
# min       0.000000e+00   0.000000e+00  1.000000e+00  1.000000e+00
# 25%       1.000000e+00   1.080000e+00  1.000000e+00  1.320000e+02
# 50%       1.000000e+00   1.820000e+00  1.000000e+00  1.610000e+02
# 75%       1.000000e+00   3.540000e+00  1.000000e+00  2.330000e+02
# max       9.000000e+00   1.852505e+05  9.900000e+01  2.650000e+02
# std       8.959539e-01   2.280398e+02  6.762597e+00  6.404389e+01
#
#        DOLocationID  payment_type   fare_amount         extra       mta_tax  \
# count  3.307234e+06  3.307234e+06  3.307234e+06  3.307234e+06  3.307234e+06
# mean   1.638013e+02  1.187126e+00  1.998804e+01  1.620755e+00  4.859043e-01
# min    1.000000e+00  0.000000e+00 -7.500000e+02 -7.500000e+00 -5.000000e-01
# 25%    1.130000e+02  1.000000e+00  9.300000e+00  0.000000e+00  5.000000e-01
# 50%    1.620000e+02  1.000000e+00  1.350000e+01  1.000000e+00  5.000000e-01
# 75%    2.340000e+02  1.000000e+00  2.260000e+01  2.500000e+00  5.000000e-01
# max    2.650000e+02  5.000000e+00  3.869836e+05  1.425000e+01  5.750000e+00
# std    7.005873e+01  5.478269e-01  2.136687e+02  1.869549e+00  1.068704e-01
#
#          tip_amount  tolls_amount  improvement_surcharge  total_amount  \
# count  3.307234e+06  3.307234e+06           3.307234e+06  3.307234e+06
# mean   3.594915e+00  6.065670e-01           9.805643e-01  2.906873e+01
# min   -9.500000e+01 -7.255000e+01          -1.000000e+00 -7.510000e+02
# 25%    1.000000e+00  0.000000e+00           1.000000e+00  1.596000e+01
# 50%    2.860000e+00  0.000000e+00           1.000000e+00  2.130000e+01
# 75%    4.480000e+00  0.000000e+00           1.000000e+00  3.130000e+01
# max    7.118800e+02  6.655600e+02           1.000000e+00  3.869876e+05
# std    4.203569e+00  2.252982e+00           1.941525e-01  2.141569e+02
#
#        congestion_surcharge   Airport_fee
# count          3.207347e+06  3.207347e+06
# mean           2.262730e+00  1.534284e-01
# min           -2.500000e+00 -1.750000e+00
# 25%            2.500000e+00  0.000000e+00
# 50%            2.500000e+00  0.000000e+00
# 75%            2.500000e+00  0.000000e+00
# max            2.500000e+00  1.750000e+00
# std            7.960739e-01  5.027511e-01

# %%
df_yellow_taxis.columns
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag',
#        'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount', 'congestion_surcharge', 'Airport_fee'],
#       dtype='object')

# %%
df_yellow_taxis.shape
# Out:
# (3307234, 19)
